# %% [markdown]
# <a href="https://colab.research.google.com/github/mohzary/python-deep-learning-f19/blob/master/Lab%202/Q6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Movie Reviews Text Classification With CNN using | hyperparameters Tuning**
#
# ---
# Dataset: Sentiment Analysis on Movie Reviews | [download](https://www.kaggle.com/c/sentiment-analysis-on-movie-reviews/data)

# %%
# To import all reqired library 

from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras import layers
from keras.preprocessing.text import Tokenizer
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#To upload movie reviews dataset file to google colab
import io
from google.colab import files

# %matplotlib inline

# %%
# To upload file from local dir to google colab
reviewsTrainFile = files.upload()
# Out:
#      <input type="file" id="files-82e98f79-e2d8-4169-81f9-5560be11cfbb" name="files[]" multiple disabled />
#      <output id="result-82e98f79-e2d8-4169-81f9-5560be11cfbb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.tsv to train.tsv

# %%
# To assign train file content to pandas object 
trainReviews = pd.read_csv(io.StringIO(reviewsTrainFile['train.tsv'].decode('utf-8')), sep='\t')

# %%
# To upload test file from local dir to google colab
reviewsTestFile = files.upload()
# Out:
#      <input type="file" id="files-b7b85983-0303-4f23-a0fd-f29816724c15" name="files[]" multiple disabled />
#      <output id="result-b7b85983-0303-4f23-a0fd-f29816724c15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.tsv to test.tsv

# %%
# To assign test file content to pandas object 
testReviews = pd.read_csv(io.StringIO(reviewsTestFile['test.tsv'].decode('utf-8')), sep='\t')

# %%
# To show the first 5 rows in trainig dataset.
trainReviews.head(5)
# Out:
#    PhraseId  ...  Sentiment
# 0         1  ...          1
# 1         2  ...          2
# 2         3  ...          2
# 3         4  ...          2
# 4         5  ...          2
#
# [5 rows x 4 columns]

# %% [markdown]
# # **The sentiment labels are:**
#
#
# *   0 - negative
# *   1 - somewhat negative
# *   2 - neutral
# *   3 - somewhat positive
# *   4 - positive

# %%
trainReviews.Sentiment.value_counts()
# Out:
# 2    79582
# 3    32927
# 1    27273
# 4     9206
# 0     7072
# Name: Sentiment, dtype: int64

# %%
#To combine negative and somewhat negative rows under one category which is negative, also somewhat positive and positive under positive label:
trainReviews.Sentiment.replace([0,4],[1,3], inplace=True)

# %%
# To count values of each leabel in our dataset
trainReviews.Sentiment.value_counts()
# Out:
# 2    79582
# 3    42133
# 1    34345
# Name: Sentiment, dtype: int64

# %% [markdown]
# # **The new sentiment labels are:**
#
#
# *   1 - negative
# *   2 - neutral
# *   3 - positive

# %%
# To show range of data, number of columns, type of features, and feature names  in the training dataset
trainReviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156060 entries, 0 to 156059
# Data columns (total 4 columns):
# PhraseId      156060 non-null int64
# SentenceId    156060 non-null int64
# Phrase        156060 non-null object
# Sentiment     156060 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 4.8+ MB

# %% [markdown]
# **To Handle Null Values**
#
# First we check if there is any null values in our training dataset

# %%
# To Show number of null values in each column in the trainig dataset:
trainNullValues = pd.DataFrame(trainReviews.isnull().sum().sort_values(ascending=False))
trainNullValues.columns = ['NO# of null values']
trainNullValues.index.name = 'Feature'
print(trainNullValues)
# Out:
#             NO# of null values
# Feature
# Sentiment                    0
# Phrase                       0
# SentenceId                   0
# PhraseId                     0

# %% [markdown]
# **There is no null values**
#
# The result shows that we have no null values in the training dataset. So, next step is to assign the Phrase and the sentiment into X and Y varaibles:

# %%
#to assign the Phrase and the sentiment into X and Y varaibles:
phrase = trainReviews['Phrase'].values
Y = trainReviews['Sentiment'].values

# %%
# To set our model parameters:
CNN_vocabulary_Size = 5000
CNN_features_Size = 300
CNN_batch_size = 250
CNN_embedding_dims = 300
CNN_filters = 250
CNN_kernel_size = 3
CNN_hidden_dims = 250
CNN_epochs = 10

# %%
#tokenizing phrase and get the vocabulary


CNN_tokenizer = Tokenizer(num_words=CNN_vocabulary_Size, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower=True, split=' ')
CNN_tokenizer.fit_on_texts(phrase)
X = CNN_tokenizer.texts_to_sequences(phrase)
X = sequence.pad_sequences(X, maxlen=CNN_features_Size)

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils.np_utils import to_categorical
CNN_labelencoder = LabelEncoder()
CNN_integer_encoded = CNN_labelencoder.fit_transform(Y)
Y = to_categorical(CNN_integer_encoded)

# %%
# To split our dataset 

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=1000)

# %%
# To create our model we use CNN_reviewsModel function we will call before the fit function, we used sequential API to create our model


def CNN_reviewsModel():
    CNN_model = Sequential()
    #We add an embedding layer as the first hidden layer in our model, number of nureons is the vocabulary size
    CNN_model.add(Embedding(CNN_vocabulary_Size,CNN_embedding_dims, input_length=CNN_features_Size))
    # we add a dropout layer 
    CNN_model.add(Dropout(0.2))
    # we add 1d convlutional layer with its filter to process the text data
    CNN_model.add(Conv1D(CNN_filters, CNN_kernel_size, padding='valid', activation='relu', strides=1))

    CNN_model.add(GlobalMaxPooling1D())
    # we add a dense layer 
    CNN_model.add(Dense(CNN_hidden_dims))

    CNN_model.add(Dropout(0.2))

    CNN_model.add(Activation('relu'))
    # our out put layer consists of 3 output nerouns
    CNN_model.add(Dense(3, activation='softmax'))
    # to compile our mode;
    CNN_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    CNN_model.summary()
    return CNN_model

# %%
# To Set up TensorBoard to visualize our model loss,acc, and graph
from keras.callbacks import TensorBoard
from keras.wrappers.scikit_learn import KerasClassifier
CNN_tbCallBack= TensorBoard(log_dir='./lab2Q5', histogram_freq=0,write_graph=True, write_images=True) 

#to call the model creation function
model = KerasClassifier(build_fn= CNN_reviewsModel,verbose=2)



# to satrt our model training
history = model.fit(X_train, Y_train, batch_size=CNN_batch_size, epochs=CNN_epochs, validation_data=(X_test, Y_test), callbacks=[CNN_tbCallBack])
# Out:
# Model: "sequential_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_39 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_77 (Dropout)         (None, 300, 300)          0
# _________________________________________________________________
# conv1d_39 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_39 (Glo (None, 250)               0
# _________________________________________________________________
# dense_77 (Dense)             (None, 250)               62750
# _________________________________________________________________
# dropout_78 (Dropout)         (None, 250)               0
# _________________________________________________________________
# activation_39 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_78 (Dense)             (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Train on 117045 samples, validate on 39015 samples
# Epoch 1/10
#  - 19s - loss: 0.7755 - acc: 0.6724 - val_loss: 0.6795 - val_acc: 0.7224
# Epoch 2/10
#  - 18s - loss: 0.6325 - acc: 0.7445 - val_loss: 0.6399 - val_acc: 0.7416
# Epoch 3/10
#  - 18s - loss: 0.5698 - acc: 0.7705 - val_loss: 0.6372 - val_acc: 0.7447
# Epoch 4/10
#  - 18s - loss: 0.5270 - acc: 0.7861 - val_loss: 0.6482 - val_acc: 0.7453
# Epoch 5/10
#  - 18s - loss: 0.4927 - acc: 0.7993 - val_loss: 0.6646 - val_acc: 0.7454
# Epoch 6/10
#  - 18s - loss: 0.4634 - acc: 0.8087 - val_loss: 0.6780 - val_acc: 0.7446
# Epoch 7/10
#  - 18s - loss: 0.4378 - acc: 0.8181 - val_loss: 0.7149 - val_acc: 0.7422
# Epoch 8/10
#  - 18s - loss: 0.4147 - acc: 0.8245 - val_loss: 0.7349 - val_acc: 0.7392
# Epoch 9/10
#  - 18s - loss: 0.3953 - acc: 0.8326 - val_loss: 0.8027 - val_acc: 0.7360
# Epoch 10/10
#  - 18s - loss: 0.3786 - acc: 0.8380 - val_loss: 0.8328 - val_acc: 0.7335

# %% [markdown]
# **Hyperparameters Tuning**
#
# Now to improve the accuracy we will use Grid Search model hyperparameter optimization technique:

# %%
# To set up GRIDESEARCHCV parameters
from sklearn.model_selection import GridSearchCV


grid_batch_size= [64,128,255]
grid_epochs = [2, 4, 6, 8]

CNN_param_grid= {'batch_size':grid_batch_size, 'epochs':grid_epochs}

CNN_grid = GridSearchCV(estimator=model, param_grid=CNN_param_grid, n_jobs=1)
CNN_grid_result= CNN_grid.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_40 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_79 (Dropout)         (None, 300, 300)          0
# _________________________________________________________________
# conv1d_40 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_40 (Glo (None, 250)               0
# _________________________________________________________________
# dense_79 (Dense)             (None, 250)               62750
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 250)               0
# _________________________________________________________________
# activation_40 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_80 (Dense)             (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
#  - 18s - loss: 0.7765 - acc: 0.6705
# Epoch 2/2
#  - 15s - loss: 0.6340 - acc: 0.7429
# Model: "sequential_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_41 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 300, 300)          0
# _________________________________________________________________
# conv1d_41 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_41 (Glo (None, 250)               0
# _________________________________________________________________
# dense_81 (Dense)             (None, 250)               62750
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 250)               0
# _________________________________________________________________
# activation_41 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_82 (Dense)             (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
#  - 18s - loss: 0.7816 - acc: 0.6691
# Epoch 2/2
#  - 15s - loss: 0.6367 - acc: 0.7422
# Model: "sequential_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_42 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_83 (Dropout)         (None, 300, 300)          0
# _________________________________________________________________
# conv1d_42 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_42 (Glo (None, 250)               0
# _________________________________________________________________
# dense_83 (Dense)             (None, 250)               62750
# _________________________________________________________________
# dropout_84 (Dropout)         (None, 250)               0
# _________________________________________________________________
# activation_42 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_84 (Dense)             (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
#  - 18s - loss: 0.7760 - acc: 0.6724
# Epoch 2/2
#  - 15s - loss: 0.6332 - acc: 0.7425
# Model: "sequential_43"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_43 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_85 (Dropout)         (None, 300, 300)          0
# _________________________________________________________________
# conv1d_43 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_43 (Glo (None, 250)               0
# _________________________________________________________________
# dense_85 (Dense)             (None, 250)               62750
# _________________________________________________________________
# dropout_86 (Dropout)         (None, 250)               0
# _________________________________________________________________
# activation_43 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_86 (Dense)             (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/4
#  - 18s - loss: 0.7744 - acc: 0.6727
# Epoch 2/4
#  - 15s - loss: 0.6310 - acc: 0.7427
# Epoch 3/4
#  - 15s - loss: 0.5602 - acc: 0.7710
# Epoch 4/4
#  - 15s - loss: 0.5059 - acc: 0.7915
# Model: "sequential_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_44 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_87 (Dropout)         (None, 300, 300)          0
# _________________________________________________________________
# conv1d_44 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_44 (Glo (None, 250)               0
# _________________________________________________________________
# dense_87 (Dense)             (None, 250)               62750
# _________________________________________________________________
# dropout_88 (Dropout)         (None, 250)               0
# _________________________________________________________________
# activation_44 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_88 (Dense)             (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/4
#  - 19s - loss: 0.7814 - acc: 0.6688
# Epoch 2/4
#  - 15s - loss: 0.6396 - acc: 0.7408
# Epoch 3/4
#  - 15s - loss: 0.5678 - acc: 0.7703
# Epoch 4/4
#  - 15s - loss: 0.5118 - acc: 0.7881
# Model: "sequential_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_45 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_89 (Dropout)         (None, 300, 300)          0
# _________________________________________________________________
# conv1d_45 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_45 (Glo (None, 250)               0
# _________________________________________________________________
# dense_89 (Dense)             (None, 250)               62750
# _________________________________________________________________
# dropout_90 (Dropout)         (None, 250)               0
# _________________________________________________________________
# activation_45 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_90 (Dense)             (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/4
#  - 18s - loss: 0.7767 - acc: 0.6734
# Epoch 2/4
#  - 15s - loss: 0.6337 - acc: 0.7419
# Epoch 3/4
#  - 15s - loss: 0.5608 - acc: 0.7711
# Epoch 4/4
#  - 15s - loss: 0.5075 - acc: 0.7911
# Model: "sequential_46"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_46 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_91 (Dropout)         (None, 300, 300)          0
# _________________________________________________________________
# conv1d_46 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_46 (Glo (None, 250)               0
# _________________________________________________________________
# dense_91 (Dense)             (None, 250)               62750
# _________________________________________________________________
# dropout_92 (Dropout)         (None, 250)               0
# _________________________________________________________________
# activation_46 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_92 (Dense)             (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/6
#  - 18s - loss: 0.7757 - acc: 0.6711
# Epoch 2/6
#  - 15s - loss: 0.6343 - acc: 0.7439
# Epoch 3/6
#  - 15s - loss: 0.5626 - acc: 0.7721
# Epoch 4/6
#  - 15s - loss: 0.5102 - acc: 0.7918
# Epoch 5/6
#  - 15s - loss: 0.4677 - acc: 0.8064
# Epoch 6/6
#  - 15s - loss: 0.4288 - acc: 0.8206
# Model: "sequential_47"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_47 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_93 (Dropout)         (None, 300, 300)          0
# _________________________________________________________________
# conv1d_47 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_47 (Glo (None, 250)               0
# _________________________________________________________________
# dense_93 (Dense)             (None, 250)               62750
# _________________________________________________________________
# dropout_94 (Dropout)         (None, 250)               0
# _________________________________________________________________
# activation_47 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_94 (Dense)             (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/6
#  - 18s - loss: 0.7764 - acc: 0.6730
# Epoch 2/6
#  - 15s - loss: 0.6348 - acc: 0.7422
# Epoch 3/6
#  - 15s - loss: 0.5621 - acc: 0.7714
# Epoch 4/6
#  - 15s - loss: 0.5080 - acc: 0.7919
# Epoch 5/6
#  - 15s - loss: 0.4638 - acc: 0.8070
# Epoch 6/6
#  - 15s - loss: 0.4271 - acc: 0.8201
# Model: "sequential_48"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_48 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_95 (Dropout)         (None, 300, 300)          0
# _________________________________________________________________
# conv1d_48 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_48 (Glo (None, 250)               0
# _________________________________________________________________
# dense_95 (Dense)             (None, 250)               62750
# _________________________________________________________________
# dropout_96 (Dropout)         (None, 250)               0
# _________________________________________________________________
# activation_48 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_96 (Dense)             (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/6
#  - 19s - loss: 0.7790 - acc: 0.6699
# Epoch 2/6
#  - 15s - loss: 0.6342 - acc: 0.7428
# Epoch 3/6
#  - 15s - loss: 0.5637 - acc: 0.7695
# Epoch 4/6
#  - 15s - loss: 0.5097 - acc: 0.7898
# Epoch 5/6
#  - 15s - loss: 0.4672 - acc: 0.8055
# Epoch 6/6
#  - 15s - loss: 0.4297 - acc: 0.8200
# Model: "sequential_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_49 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_97 (Dropout)         (None, 300, 300)          0
# _________________________________________________________________
# conv1d_49 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_49 (Glo (None, 250)               0
# _________________________________________________________________
# dense_97 (Dense)             (None, 250)               62750
# _________________________________________________________________
# dropout_98 (Dropout)         (None, 250)               0
# _________________________________________________________________
# activation_49 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_98 (Dense)             (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/8
#  - 19s - loss: 0.7748 - acc: 0.6713
# Epoch 2/8
#  - 15s - loss: 0.6346 - acc: 0.7427
# Epoch 3/8
#  - 15s - loss: 0.5629 - acc: 0.7704
# Epoch 4/8
#  - 15s - loss: 0.5079 - acc: 0.7911
# Epoch 5/8
#  - 15s - loss: 0.4641 - acc: 0.8069
# Epoch 6/8
#  - 15s - loss: 0.4280 - acc: 0.8204
# Epoch 7/8
#  - 15s - loss: 0.3966 - acc: 0.8308
# Epoch 8/8
#  - 15s - loss: 0.3698 - acc: 0.8400
# Model: "sequential_50"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_50 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_99 (Dropout)         (None, 300, 300)          0
# _________________________________________________________________
# conv1d_50 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_50 (Glo (None, 250)               0
# _________________________________________________________________
# dense_99 (Dense)             (None, 250)               62750
# _________________________________________________________________
# dropout_100 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_50 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_100 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/8
#  - 19s - loss: 0.7785 - acc: 0.6699
# Epoch 2/8
#  - 15s - loss: 0.6366 - acc: 0.7425
# Epoch 3/8
#  - 15s - loss: 0.5656 - acc: 0.7701
# Epoch 4/8
#  - 15s - loss: 0.5101 - acc: 0.7906
# Epoch 5/8
#  - 15s - loss: 0.4670 - acc: 0.8060
# Epoch 6/8
#  - 15s - loss: 0.4283 - acc: 0.8189
# Epoch 7/8
#  - 15s - loss: 0.3991 - acc: 0.8302
# Epoch 8/8
#  - 15s - loss: 0.3739 - acc: 0.8387
# Model: "sequential_51"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_51 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_101 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_51 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_51 (Glo (None, 250)               0
# _________________________________________________________________
# dense_101 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_102 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_51 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_102 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/8
#  - 19s - loss: 0.7750 - acc: 0.6739
# Epoch 2/8
#  - 15s - loss: 0.6339 - acc: 0.7413
# Epoch 3/8
#  - 15s - loss: 0.5614 - acc: 0.7711
# Epoch 4/8
#  - 15s - loss: 0.5079 - acc: 0.7908
# Epoch 5/8
#  - 15s - loss: 0.4668 - acc: 0.8066
# Epoch 6/8
#  - 15s - loss: 0.4286 - acc: 0.8192
# Epoch 7/8
#  - 15s - loss: 0.3968 - acc: 0.8310
# Epoch 8/8
#  - 15s - loss: 0.3708 - acc: 0.8433
# Model: "sequential_52"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_52 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_103 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_52 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_52 (Glo (None, 250)               0
# _________________________________________________________________
# dense_103 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_104 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_52 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_104 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
#  - 17s - loss: 0.7837 - acc: 0.6655
# Epoch 2/2
#  - 12s - loss: 0.6344 - acc: 0.7426
# Model: "sequential_53"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_53 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_105 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_53 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_53 (Glo (None, 250)               0
# _________________________________________________________________
# dense_105 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_106 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_53 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_106 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
#  - 16s - loss: 0.7898 - acc: 0.6636
# Epoch 2/2
#  - 12s - loss: 0.6361 - acc: 0.7422
# Model: "sequential_54"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_54 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_107 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_54 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_54 (Glo (None, 250)               0
# _________________________________________________________________
# dense_107 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_108 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_54 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_108 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
#  - 17s - loss: 0.7858 - acc: 0.6653
# Epoch 2/2
#  - 12s - loss: 0.6360 - acc: 0.7421
# Model: "sequential_55"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_55 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_109 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_55 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_55 (Glo (None, 250)               0
# _________________________________________________________________
# dense_109 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_110 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_55 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_110 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/4
#  - 17s - loss: 0.7868 - acc: 0.6639
# Epoch 2/4
#  - 12s - loss: 0.6362 - acc: 0.7421
# Epoch 3/4
#  - 12s - loss: 0.5610 - acc: 0.7719
# Epoch 4/4
#  - 12s - loss: 0.5079 - acc: 0.7936
# Model: "sequential_56"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_56 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_111 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_56 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_56 (Glo (None, 250)               0
# _________________________________________________________________
# dense_111 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_112 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_56 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_112 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/4
#  - 17s - loss: 0.7852 - acc: 0.6660
# Epoch 2/4
#  - 12s - loss: 0.6364 - acc: 0.7426
# Epoch 3/4
#  - 12s - loss: 0.5638 - acc: 0.7724
# Epoch 4/4
#  - 12s - loss: 0.5077 - acc: 0.7928
# Model: "sequential_57"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_57 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_113 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_57 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_57 (Glo (None, 250)               0
# _________________________________________________________________
# dense_113 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_114 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_57 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_114 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/4
#  - 17s - loss: 0.7890 - acc: 0.6631
# Epoch 2/4
#  - 12s - loss: 0.6376 - acc: 0.7423
# Epoch 3/4
#  - 12s - loss: 0.5648 - acc: 0.7712
# Epoch 4/4
#  - 12s - loss: 0.5092 - acc: 0.7927
# Model: "sequential_58"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_58 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_115 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_58 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_58 (Glo (None, 250)               0
# _________________________________________________________________
# dense_115 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_116 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_58 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_116 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/6
#  - 17s - loss: 0.7870 - acc: 0.6640
# Epoch 2/6
#  - 12s - loss: 0.6369 - acc: 0.7419
# Epoch 3/6
#  - 12s - loss: 0.5642 - acc: 0.7720
# Epoch 4/6
#  - 12s - loss: 0.5079 - acc: 0.7936
# Epoch 5/6
#  - 12s - loss: 0.4623 - acc: 0.8111
# Epoch 6/6
#  - 12s - loss: 0.4239 - acc: 0.8246
# Model: "sequential_59"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_59 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_117 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_59 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_59 (Glo (None, 250)               0
# _________________________________________________________________
# dense_117 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_118 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_59 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_118 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/6
#  - 17s - loss: 0.7876 - acc: 0.6647
# Epoch 2/6
#  - 12s - loss: 0.6393 - acc: 0.7411
# Epoch 3/6
#  - 12s - loss: 0.5651 - acc: 0.7719
# Epoch 4/6
#  - 12s - loss: 0.5086 - acc: 0.7946
# Epoch 5/6
#  - 12s - loss: 0.4639 - acc: 0.8089
# Epoch 6/6
#  - 12s - loss: 0.4257 - acc: 0.8220
# Model: "sequential_60"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_60 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_119 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_60 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_60 (Glo (None, 250)               0
# _________________________________________________________________
# dense_119 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_120 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_60 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_120 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/6
#  - 17s - loss: 0.7889 - acc: 0.6644
# Epoch 2/6
#  - 12s - loss: 0.6378 - acc: 0.7416
# Epoch 3/6
#  - 12s - loss: 0.5652 - acc: 0.7718
# Epoch 4/6
#  - 12s - loss: 0.5098 - acc: 0.7922
# Epoch 5/6
#  - 12s - loss: 0.4663 - acc: 0.8096
# Epoch 6/6
#  - 12s - loss: 0.4263 - acc: 0.8252
# Model: "sequential_61"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_61 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_121 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_61 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_61 (Glo (None, 250)               0
# _________________________________________________________________
# dense_121 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_122 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_61 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_122 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/8
#  - 17s - loss: 0.7855 - acc: 0.6664
# Epoch 2/8
#  - 12s - loss: 0.6353 - acc: 0.7431
# Epoch 3/8
#  - 12s - loss: 0.5605 - acc: 0.7736
# Epoch 4/8
#  - 12s - loss: 0.5054 - acc: 0.7943
# Epoch 5/8
#  - 12s - loss: 0.4610 - acc: 0.8110
# Epoch 6/8
#  - 12s - loss: 0.4240 - acc: 0.8246
# Epoch 7/8
#  - 12s - loss: 0.3924 - acc: 0.8364
# Epoch 8/8
#  - 12s - loss: 0.3631 - acc: 0.8464
# Model: "sequential_62"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_62 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_123 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_62 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_62 (Glo (None, 250)               0
# _________________________________________________________________
# dense_123 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_124 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_62 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_124 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/8
#  - 18s - loss: 0.7887 - acc: 0.6641
# Epoch 2/8
#  - 12s - loss: 0.6407 - acc: 0.7420
# Epoch 3/8
#  - 12s - loss: 0.5663 - acc: 0.7701
# Epoch 4/8
#  - 12s - loss: 0.5105 - acc: 0.7915
# Epoch 5/8
#  - 12s - loss: 0.4641 - acc: 0.8079
# Epoch 6/8
#  - 13s - loss: 0.4272 - acc: 0.8210
# Epoch 7/8
#  - 12s - loss: 0.3930 - acc: 0.8342
# Epoch 8/8
#  - 12s - loss: 0.3664 - acc: 0.8436
# Model: "sequential_63"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_63 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_125 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_63 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_63 (Glo (None, 250)               0
# _________________________________________________________________
# dense_125 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_126 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_63 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_126 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/8
#  - 18s - loss: 0.7840 - acc: 0.6660
# Epoch 2/8
#  - 12s - loss: 0.6371 - acc: 0.7415
# Epoch 3/8
#  - 12s - loss: 0.5633 - acc: 0.7693
# Epoch 4/8
#  - 12s - loss: 0.5078 - acc: 0.7930
# Epoch 5/8
#  - 13s - loss: 0.4647 - acc: 0.8085
# Epoch 6/8
#  - 12s - loss: 0.4269 - acc: 0.8210
# Epoch 7/8
#  - 12s - loss: 0.3957 - acc: 0.8339
# Epoch 8/8
#  - 12s - loss: 0.3687 - acc: 0.8442
# Model: "sequential_64"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_64 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_127 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_64 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_64 (Glo (None, 250)               0
# _________________________________________________________________
# dense_127 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_128 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_64 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_128 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
#  - 16s - loss: 0.8085 - acc: 0.6523
# Epoch 2/2
#  - 11s - loss: 0.6467 - acc: 0.7386
# Model: "sequential_65"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_65 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_129 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_65 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_65 (Glo (None, 250)               0
# _________________________________________________________________
# dense_129 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_130 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_65 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_130 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
#  - 16s - loss: 0.8061 - acc: 0.6554
# Epoch 2/2
#  - 11s - loss: 0.6480 - acc: 0.7386
# Model: "sequential_66"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_66 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_131 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_66 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_66 (Glo (None, 250)               0
# _________________________________________________________________
# dense_131 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_132 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_66 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_132 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
#  - 17s - loss: 0.8078 - acc: 0.6520
# Epoch 2/2
#  - 11s - loss: 0.6449 - acc: 0.7393
# Model: "sequential_67"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_67 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_133 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_67 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_67 (Glo (None, 250)               0
# _________________________________________________________________
# dense_133 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_134 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_67 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_134 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/4
#  - 17s - loss: 0.8046 - acc: 0.6527
# Epoch 2/4
#  - 11s - loss: 0.6457 - acc: 0.7394
# Epoch 3/4
#  - 11s - loss: 0.5715 - acc: 0.7705
# Epoch 4/4
#  - 11s - loss: 0.5150 - acc: 0.7930
# Model: "sequential_68"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_68 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_135 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_68 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_68 (Glo (None, 250)               0
# _________________________________________________________________
# dense_135 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_136 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_68 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_136 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/4
#  - 17s - loss: 0.8118 - acc: 0.6517
# Epoch 2/4
#  - 11s - loss: 0.6489 - acc: 0.7387
# Epoch 3/4
#  - 11s - loss: 0.5750 - acc: 0.7683
# Epoch 4/4
#  - 11s - loss: 0.5182 - acc: 0.7910
# Model: "sequential_69"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_69 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_137 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_69 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_69 (Glo (None, 250)               0
# _________________________________________________________________
# dense_137 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_138 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_69 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_138 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/4
#  - 17s - loss: 0.8069 - acc: 0.6550
# Epoch 2/4
#  - 11s - loss: 0.6474 - acc: 0.7387
# Epoch 3/4
#  - 11s - loss: 0.5734 - acc: 0.7693
# Epoch 4/4
#  - 11s - loss: 0.5173 - acc: 0.7916
# Model: "sequential_70"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_70 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_139 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_70 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_70 (Glo (None, 250)               0
# _________________________________________________________________
# dense_139 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_140 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_70 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_140 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/6
#  - 17s - loss: 0.8074 - acc: 0.6520
# Epoch 2/6
#  - 11s - loss: 0.6446 - acc: 0.7391
# Epoch 3/6
#  - 11s - loss: 0.5728 - acc: 0.7708
# Epoch 4/6
#  - 11s - loss: 0.5188 - acc: 0.7921
# Epoch 5/6
#  - 11s - loss: 0.4736 - acc: 0.8097
# Epoch 6/6
#  - 11s - loss: 0.4360 - acc: 0.8233
# Model: "sequential_71"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_71 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_141 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_71 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_71 (Glo (None, 250)               0
# _________________________________________________________________
# dense_141 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_142 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_71 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_142 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/6
#  - 17s - loss: 0.8163 - acc: 0.6488
# Epoch 2/6
#  - 11s - loss: 0.6540 - acc: 0.7360
# Epoch 3/6
#  - 11s - loss: 0.5802 - acc: 0.7662
# Epoch 4/6
#  - 11s - loss: 0.5217 - acc: 0.7898
# Epoch 5/6
#  - 11s - loss: 0.4749 - acc: 0.8084
# Epoch 6/6
#  - 11s - loss: 0.4365 - acc: 0.8234
# Model: "sequential_72"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_72 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_143 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_72 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_72 (Glo (None, 250)               0
# _________________________________________________________________
# dense_143 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_144 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_72 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_144 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/6
#  - 17s - loss: 0.7987 - acc: 0.6566
# Epoch 2/6
#  - 11s - loss: 0.6432 - acc: 0.7393
# Epoch 3/6
#  - 11s - loss: 0.5714 - acc: 0.7698
# Epoch 4/6
#  - 11s - loss: 0.5151 - acc: 0.7899
# Epoch 5/6
#  - 11s - loss: 0.4688 - acc: 0.8087
# Epoch 6/6
#  - 11s - loss: 0.4326 - acc: 0.8235
# Model: "sequential_73"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_73 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_145 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_73 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_73 (Glo (None, 250)               0
# _________________________________________________________________
# dense_145 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_146 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_73 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_146 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/8
#  - 17s - loss: 0.8036 - acc: 0.6533
# Epoch 2/8
#  - 11s - loss: 0.6437 - acc: 0.7401
# Epoch 3/8
#  - 11s - loss: 0.5713 - acc: 0.7701
# Epoch 4/8
#  - 11s - loss: 0.5131 - acc: 0.7930
# Epoch 5/8
#  - 11s - loss: 0.4684 - acc: 0.8115
# Epoch 6/8
#  - 11s - loss: 0.4315 - acc: 0.8243
# Epoch 7/8
#  - 11s - loss: 0.3999 - acc: 0.8368
# Epoch 8/8
#  - 11s - loss: 0.3707 - acc: 0.8481
# Model: "sequential_74"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_74 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_147 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_74 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_74 (Glo (None, 250)               0
# _________________________________________________________________
# dense_147 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_148 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_74 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_148 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/8
#  - 17s - loss: 0.8037 - acc: 0.6540
# Epoch 2/8
#  - 11s - loss: 0.6446 - acc: 0.7400
# Epoch 3/8
#  - 11s - loss: 0.5719 - acc: 0.7697
# Epoch 4/8
#  - 11s - loss: 0.5153 - acc: 0.7926
# Epoch 5/8
#  - 11s - loss: 0.4699 - acc: 0.8093
# Epoch 6/8
#  - 11s - loss: 0.4316 - acc: 0.8253
# Epoch 7/8
#  - 11s - loss: 0.3997 - acc: 0.8365
# Epoch 8/8
#  - 11s - loss: 0.3694 - acc: 0.8483
# Model: "sequential_75"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_75 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_149 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_75 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_75 (Glo (None, 250)               0
# _________________________________________________________________
# dense_149 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_150 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_75 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_150 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/8
#  - 17s - loss: 0.8028 - acc: 0.6561
# Epoch 2/8
#  - 11s - loss: 0.6428 - acc: 0.7396
# Epoch 3/8
#  - 11s - loss: 0.5696 - acc: 0.7698
# Epoch 4/8
#  - 11s - loss: 0.5146 - acc: 0.7912
# Epoch 5/8
#  - 11s - loss: 0.4684 - acc: 0.8091
# Epoch 6/8
#  - 11s - loss: 0.4306 - acc: 0.8237
# Epoch 7/8
#  - 11s - loss: 0.3979 - acc: 0.8383
# Epoch 8/8
#  - 11s - loss: 0.3691 - acc: 0.8488
# Model: "sequential_76"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_76 (Embedding)     (None, 300, 300)          1500000
# _________________________________________________________________
# dropout_151 (Dropout)        (None, 300, 300)          0
# _________________________________________________________________
# conv1d_76 (Conv1D)           (None, 298, 250)          225250
# _________________________________________________________________
# global_max_pooling1d_76 (Glo (None, 250)               0
# _________________________________________________________________
# dense_151 (Dense)            (None, 250)               62750
# _________________________________________________________________
# dropout_152 (Dropout)        (None, 250)               0
# _________________________________________________________________
# activation_76 (Activation)   (None, 250)               0
# _________________________________________________________________
# dense_152 (Dense)            (None, 3)                 753
# =================================================================
# Total params: 1,788,753
# Trainable params: 1,788,753
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/4
#  - 25s - loss: 0.7558 - acc: 0.6816
# Epoch 2/4
#  - 19s - loss: 0.6232 - acc: 0.7477
# Epoch 3/4
#  - 19s - loss: 0.5631 - acc: 0.7714
# Epoch 4/4
#  - 19s - loss: 0.5212 - acc: 0.7864

# %%
# To show the gridsearch results
print("Best: %f using %s" % (CNN_grid_result.best_score_, CNN_grid_result.best_params_))
# Out:
# Best: 0.729489 using {'batch_size': 128, 'epochs': 4}
